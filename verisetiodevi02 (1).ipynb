# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv("Food Waste data and research - by country.csv")
df
# Out:
#                         Country  combined figures (kg/capita/year)  \
# 0                   Afghanistan                                126
# 1                       Albania                                127
# 2                       Algeria                                135
# 3                       Andorra                                123
# 4                        Angola                                144
# ..                          ...                                ...
# 209  Venezuela (Boliv. Rep. of)                                116
# 210                    Viet Nam                                120
# 211                       Yemen                                148
# 212                      Zambia                                122
# 213                    Zimbabwe                                144
#
#      Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 0                                     82                           3109153
# ...

# %%
df.shape
# Out:
# (214, 12)

# %%
df.columns
# Out:
# Index(['Country', 'combined figures (kg/capita/year)',
#        'Household estimate (kg/capita/year)',
#        'Household estimate (tonnes/year)', 'Retail estimate (kg/capita/year)',
#        'Retail estimate (tonnes/year)',
#        'Food service estimate (kg/capita/year)',
#        'Food service estimate (tonnes/year)', 'Confidence in estimate',
#        'M49 code', 'Region', 'Source'],
#       dtype='object')

# %%
df.head()
# Out:
#        Country  combined figures (kg/capita/year)  \
# 0  Afghanistan                                126
# 1      Albania                                127
# 2      Algeria                                135
# 3      Andorra                                123
# 4       Angola                                144
#
#    Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 0                                   82                           3109153
# 1                                   83                            238492
# 2                                   91                           3918529
# 3                                   84                              6497
# 4                                  100                           3169523
#
#    Retail estimate (kg/capita/year)  Retail estimate (tonnes/year)  \
# 0                                16                         594982
# 1                                16                          45058
# ...

# %%
df.drop('Source',axis=1,inplace=True)
df
# Out:
#                         Country  combined figures (kg/capita/year)  \
# 0                   Afghanistan                                126
# 1                       Albania                                127
# 2                       Algeria                                135
# 3                       Andorra                                123
# 4                        Angola                                144
# ..                          ...                                ...
# 209  Venezuela (Boliv. Rep. of)                                116
# 210                    Viet Nam                                120
# 211                       Yemen                                148
# 212                      Zambia                                122
# 213                    Zimbabwe                                144
#
#      Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 0                                     82                           3109153
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 11 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Country                                 214 non-null    object
#  1   combined figures (kg/capita/year)       214 non-null    int64
#  2   Household estimate (kg/capita/year)     214 non-null    int64
#  3   Household estimate (tonnes/year)        214 non-null    int64
#  4   Retail estimate (kg/capita/year)        214 non-null    int64
#  5   Retail estimate (tonnes/year)           214 non-null    int64
#  6   Food service estimate (kg/capita/year)  214 non-null    int64
#  7   Food service estimate (tonnes/year)     214 non-null    int64
#  8   Confidence in estimate                  214 non-null    object
#  9   M49 code                                214 non-null    int64
# ...

# %%
df.isnull().any()
# Out:
# Country                                   False
# combined figures (kg/capita/year)         False
# Household estimate (kg/capita/year)       False
# Household estimate (tonnes/year)          False
# Retail estimate (kg/capita/year)          False
# Retail estimate (tonnes/year)             False
# Food service estimate (kg/capita/year)    False
# Food service estimate (tonnes/year)       False
# Confidence in estimate                    False
# M49 code                                  False
# Region                                    False
# dtype: bool

# %%
df.describe()
# Out:
#        combined figures (kg/capita/year)  Household estimate (kg/capita/year)  \
# count                         214.000000                           214.000000
# mean                          126.794393                            84.294393
# std                            22.157879                            18.313705
# min                            61.000000                            33.000000
# 25%                           115.000000                            74.000000
# 50%                           123.000000                            80.000000
# 75%                           137.750000                            95.000000
# max                           260.000000                           189.000000
#
#        Household estimate (tonnes/year)  Retail estimate (kg/capita/year)  \
# count                      2.140000e+02                        214.000000
# mean                       2.658896e+06                         15.116822
# ...

# %%
df["Country"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia (Plurin. State of)',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Chile', 'China', 'China, Hong Kong SAR', 'China, Macao SAR',
#        'Colombia', 'Comoros', 'Congo', 'Costa Rica', 'Côte d’Ivoire',
#        'Croatia', 'Cuba', 'Curaçao', 'Cyprus', 'Czechia',
#        "Dem. People's Rep. Korea", 'Dem. Rep. of the Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
df["Region"].unique()
# Out:
# array(['Southern Asia', 'Southern Europe', 'Northern Africa',
#        'Sub-Saharan Africa', 'Latin America and the Caribbean',
#        'Western Asia', 'Australia and New Zealand', 'Western Europe',
#        'Eastern Europe', 'Northern America', 'South-eastern Asia',
#        'Eastern Asia', 'Northern Europe', 'Melanesia', 'Polynesia',
#        'Micronesia', 'Central Asia'], dtype=object)

# %%
df["Confidence in estimate"].unique()
# Out:
# array(['Very Low Confidence', 'Low Confidence', 'High Confidence',
#        'Medium Confidence'], dtype=object)

# %%
df["Confidence in estimate"].value_counts()
# Out:
# Confidence in estimate
# Very Low Confidence    130
# Low Confidence          61
# Medium Confidence       13
# High Confidence         10
# Name: count, dtype: int64

# %%
df["Region"].value_counts()
# Out:
# Region
# Sub-Saharan Africa                 48
# Latin America and the Caribbean    42
# Western Asia                       18
# Southern Europe                    15
# Northern Europe                    12
# South-eastern Asia                 11
# Eastern Europe                     10
# Southern Asia                       9
# Western Europe                      9
# Eastern Asia                        7
# Micronesia                          7
# Northern Africa                     6
# Melanesia                           5
# Central Asia                        5
# Northern America                    4
# Polynesia                           4
# Australia and New Zealand           2
# Name: count, dtype: int64

# %%
df[df["Confidence in estimate"] == "Very Low Confidence"]
# Out:
#                         Country  combined figures (kg/capita/year)  \
# 0                   Afghanistan                                126
# 1                       Albania                                127
# 2                       Algeria                                135
# 4                        Angola                                144
# 6                     Argentina                                116
# ..                          ...                                ...
# 209  Venezuela (Boliv. Rep. of)                                116
# 210                    Viet Nam                                120
# 211                       Yemen                                148
# 212                      Zambia                                122
# 213                    Zimbabwe                                144
#
#      Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 0                                     82                           3109153
# ...

# %%
most_common_region = df['Region'].mode()[0]
most_common_region
# Out:
# 'Sub-Saharan Africa'

# %%
most_common_confidence = df['Confidence in estimate'].mode()[0]
most_common_confidence
# Out:
# 'Very Low Confidence'

# %%
region_m49 = df.groupby("Region")[["M49 code"]].mean().reset_index()
region_m49
# Out:
#                              Region    M49 code
# 0         Australia and New Zealand  295.000000
# 1                      Central Asia  646.400000
# 2                      Eastern Asia  378.857143
# 3                    Eastern Europe  466.900000
# 4   Latin America and the Caribbean  400.023810
# 5                         Melanesia  403.600000
# 6                        Micronesia  494.857143
# 7                   Northern Africa  547.500000
# 8                  Northern America  332.000000
# 9                   Northern Europe  458.500000
# 10                        Polynesia  678.500000
# 11               South-eastern Asia  450.545455
# 12                    Southern Asia  283.777778
# 13                  Southern Europe  429.866667
# 14               Sub-Saharan Africa  447.479167
# 15                     Western Asia  438.888889
# 16                   Western Europe  364.222222

# %%
df.hist(figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'combined figures (kg/capita/year)'}>,
#         <Axes: title={'center': 'Household estimate (kg/capita/year)'}>,
#         <Axes: title={'center': 'Household estimate (tonnes/year)'}>],
#        [<Axes: title={'center': 'Retail estimate (kg/capita/year)'}>,
#         <Axes: title={'center': 'Retail estimate (tonnes/year)'}>,
#         <Axes: title={'center': 'Food service estimate (kg/capita/year)'}>],
#        [<Axes: title={'center': 'Food service estimate (tonnes/year)'}>,
#         <Axes: title={'center': 'M49 code'}>, <Axes: >]], dtype=object)

# %%
sns.displot(df['Confidence in estimate'])
plt.xticks(rotation=90)
plt.show()

# %%
group_region_m49 = df.groupby("Region")[["M49 code"]].mean().reset_index()
plt.figure(figsize=(10,6))
plt.bar(x = "Region", height = "M49 code", data = group_region_m49)
plt.xticks(rotation=90);
plt.xlabel("Region")
plt.ylabel("Average M49 Code")
plt.title("Average M49 Code by Region")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x = "Region", y = "M49 code",data=df)
plt.xticks(rotation = 90)
plt.show()

# %%
group_confidence_combined = df.groupby("Confidence in estimate")[["combined figures (kg/capita/year)"]].mean().reset_index()
plt.figure(figsize=(8,5))
plt.bar(x = "Confidence in estimate", height= "combined figures (kg/capita/year)", data = group_confidence_combined)
plt.xticks(rotation=90);
plt.xlabel("Confidence in estimate")
plt.ylabel("combined figures (kg/capita/year)")
plt.title("Combined figures by Confidence in estimate")
plt.show()

# %%
confidence_in_estimate = df['Confidence in estimate'].value_counts()
confidence_in_estimate.plot(kind='pie', autopct='%1.1f%%')
plt.title("Confidence in estimate")
plt.ylabel('')
plt.show()

# %%
region = df['Region'].value_counts()
region.plot(kind='pie', autopct='%1.1f%%')
plt.title("Region")
plt.ylabel('')
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
df.drop('Country',axis=1,inplace=True)
df.drop('M49 code',axis=1,inplace=True)

# %%
df.head()
# Out:
#    combined figures (kg/capita/year)  Household estimate (kg/capita/year)  \
# 0                                126                                   82
# 1                                127                                   83
# 2                                135                                   91
# 3                                123                                   84
# 4                                144                                  100
#
#    Household estimate (tonnes/year)  Retail estimate (kg/capita/year)  \
# 0                           3109153                                16
# 1                            238492                                16
# 2                           3918529                                16
# 3                              6497                                13
# 4                           3169523                                16
#
#    Retail estimate (tonnes/year)  Food service estimate (kg/capita/year)  \
# ...

# %%
df = pd.get_dummies(df, columns=["Region"], drop_first=True)

# %%
enc = LabelEncoder()
df[["Confidence in estimate"]] = df[["Confidence in estimate"]].apply(enc.fit_transform)

# %%
df
# Out:
#      combined figures (kg/capita/year)  Household estimate (kg/capita/year)  \
# 0                                  126                                   82
# 1                                  127                                   83
# 2                                  135                                   91
# 3                                  123                                   84
# 4                                  144                                  100
# ..                                 ...                                  ...
# 209                                116                                   72
# 210                                120                                   76
# 211                                148                                  104
# 212                                122                                   78
# 213                                144                                  100
#
# ...

# %%
X = df.drop("Retail estimate (tonnes/year)",axis=1)
y = df["Retail estimate (tonnes/year)"]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

ss=StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Define the model
rf_model = RandomForestRegressor(random_state=42)

# Define the hyperparameters to tune
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Use GridSearchCV to find the best hyperparameters
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=5, n_jobs=-1, scoring='r2')
grid_search.fit(X_train, y_train)

# Get the best model
best_rf_model = grid_search.best_estimator_

# Evaluate the best model
y_pred = best_rf_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2_score = best_rf_model.score(X_test, y_test)

print(f'Mean Absolute Error: {mae}')
print(f'Mean Squared Error: {mse}')
print(f'R^2 Score: {r2_score}')
# Out:
# Mean Absolute Error: 81374.95523326274
# Mean Squared Error: 51131999080.53116
# R^2 Score: 0.9315218178928305

# %%
comparison = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(comparison.head(20))
# Out:
#       Actual     Predicted
# 161     2859  1.890560e+03
# 112    35354  3.639331e+04
# 167   673502  5.211945e+05
# 178   915865  7.473351e+05
# 82    199744  1.939966e+05
# 70      3578  3.805616e+03
# 204  5151313  4.474109e+06
# 9     238248  3.368301e+05
# 123  1995310  2.971540e+06
# 192     1634  1.623965e+03
# 108    33240  3.458047e+04
# 196    92936  8.201521e+04
# 139  3143117  3.549967e+06
# 198      181  3.919435e+02
# 155   656263  6.854545e+05
# 4     497755  5.267306e+05
# 59   1570093  1.432612e+06
# 32    257853  2.540223e+05
# 26       384  5.008691e+02
# 79      1752  1.713718e+03
